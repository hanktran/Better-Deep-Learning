# %%
# rectified linear function
def rectified(x):
    return max(0.0, x)

# %%
rectified(1.0)
# Out:
# 1.0

# %%
rectified(1000.0)
# Out:
# 1000.0

# %%
rectified(0.0)
# Out:
# 0.0

# %%
rectified(-1.0)
# Out:
# 0.0

# %%
rectified(-1000.0)
# Out:
# 0.0
